# %% [markdown]
# # sql with python

# %%
import mysql.connector

# %%
sql = mysql.connector.connect(
    host= "127.0.0.1",
    user = "root",
    password = "mysql"
)

# %%
print(sql)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000013713EB9810>

# %%
print(sql.is_connected())
# Out:
# True

# %%
cur  = sql.cursor()

# %%
cur.execute("show databases;")

# %%
cur.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('sys',),
#  ('world',)]

# %%
cur.fetchall()
# Out:
# []

# %%
cur.execute("show databases")
cur.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('sys',),
#  ('world',)]

# %%
cur.execute("create database students")

# %%
cur.execute("use students")

# %%
cur.execute("create table class1 (name varchar(20),rollno int(100),phone int(10))" )

# %%
cur.execute("INSERT into class1 values('ashwani',10,0123456789)")

# %%
cur.execute("select * from class1")

# %%
cur.fetchall()
# Out:
# [('ashwani', 10, 1111111), ('ashwani', 10, 123456789)]

# %%
sql.commit()

# %%
cur.execute("select * from class1")
for i in cur:
    print(i)
# Out:
# ('ashwani', 10, 1111111)
# ('ashwani', 10, 123456789)
