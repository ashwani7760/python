# %% [markdown]
# # sql with python

# %%
import mysql.connector

# %%
sql = mysql.connector.connect(
    host= "127.0.0.1",
    user = "root",
    password = "mysql"
)

# %%
print(sql)

# %%
print(sql.is_connected())
# Out:
# True

# %%
cur  = sql.cursor()

# %%
cur.execute("show databases;")

# %%
cur.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('students',),
#  ('sys',),
#  ('world',)]

# %%
cur.fetchall()
# Out:
# []

# %%
cur.execute("show databases")
cur.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('students',),
#  ('sys',),
#  ('world',)]

# %%
cur.execute("create database students")

# %%
cur.execute("use students")

# %%
cur.execute("create table class1 (name varchar(20),rollno int(100),phone int(10))" )

# %%
cur.execute("INSERT into class1 values('ashwani',10,0123456789)")

# %%
cur.execute("select * from class1")

# %%
cur.fetchall()
# Out:
# [('ashwani', 10, 1111111),
#  ('ashwani', 10, 123456789),
#  ('ashwani', 10, 123456789)]

# %%
sql.commit()

# %%
cur.execute("select * from class1")
for i in cur:
    print(i)
# Out:
# ('ashwani', 10, 1111111)
# ('ashwani', 10, 123456789)
# ('ashwani', 10, 123456789)

# %%
# alternate of use database
cur.execute("select * from students.class1")

# %%
cur.fetchall()
# Out:
# [('ashwani', 10, 1111111),
#  ('ashwani', 10, 123456789),
#  ('ashwani', 10, 123456789)]

# %%
cur.execute("create table students.classbtech (id int, first_name varchar(50), last_name varchar(50), regdate DATe)")

# %%
cur.execute("insert into students.classbtech values (56,'shenak','akhtar','2022-12-11')")

# %%
sql.commit()

# %%
cur.execute("insert into students.classbtech values ,(56,'shenak','akhtar','2022-12-11'),(56,'shenak','akhtar','2022-12-11'),
(56,'shenak','akhtar','2022-12-11'),(56,'shenak','akhtar','2022-12-11')")
# Out:
#   Cell In[24], line 1
#     cur.execute("insert into students.classbtech values ,(56,'shenak','akhtar','2022-12-11'),(56,'shenak','akhtar','2022-12-11'),
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
cur.execute("""insert into students.classbtech values (57,'shenak','akhtar','2022-12-11'),(58,'shenak','akhtar','2022-12-11'),
(59,'shenak','akhtar','2022-12-11'),(60,'shenak','akhtar','2022-12-11')""")

# %%
cur.execute("select * from students.classbtech;")

# %%
cur.fetchall()
# Out:
# [(56, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (57, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (58, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (59, 'salim', 'akhtar', datetime.date(2022, 12, 11)),
#  (60, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (56, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (57, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (58, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (59, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (60, 'shenak', 'akhtar', datetime.date(2022, 12, 11))]

# %%
cur.execute("select id,first_name from classbtech")

# %%
cur.fetchall()
# Out:
# [(56, 'shenak'),
#  (57, 'shenak'),
#  (58, 'shenak'),
#  (59, 'salim'),
#  (60, 'shenak'),
#  (56, 'shenak'),
#  (57, 'shenak'),
#  (58, 'shenak'),
#  (59, 'shenak'),
#  (60, 'shenak')]

# %%
cur.execute("select * from classbtech where id =59")

# %%
cur.fetchall()
# Out:
# [(59, 'salim', 'akhtar', datetime.date(2022, 12, 11)),
#  (59, 'shenak', 'akhtar', datetime.date(2022, 12, 11))]

# %%
cur.execute("update students.classbtech set first_name= 'salim' where id = 59")

# %%
cur.execute("select * from classbtech where id =59")
cur.fetchall()
# Out:
# [(59, 'salim', 'akhtar', datetime.date(2022, 12, 11)),
#  (59, 'salim', 'akhtar', datetime.date(2022, 12, 11))]

# %%
sql.commit()

# %%
cur.execute("delete from students.classbtech where last_name = 'akhtar'")

# %%
cur.execute("select * from students.classbtech")
cur.fetchall()
# Out:
# []

# %%
cur.execute("select min(id) from students.classbtech")

# %%
cur.fetchall()
# Out:
# [(None,)]

# %%
cur.execute("""insert into students.classbtech values (57,'shenak','akhtar','2022-12-11'),(58,'shenak','akhtar','2022-12-11'),
(59,'shenak','akhtar','2022-12-11'),(60,'shenak','akhtar','2022-12-11')""")

# %%
cur.execute("select * from students.classbtech")

# %%
cur.fetchall()
# Out:
# [(57, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (58, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (59, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (60, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (57, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (58, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (59, 'shenak', 'akhtar', datetime.date(2022, 12, 11)),
#  (60, 'shenak', 'akhtar', datetime.date(2022, 12, 11))]

# %%
cur.execute("select count(*) from students.classbtech")
cur.fetchall()
# Out:
# [(8,)]

# %%
cur.execute("drop table students.class1")

# %%
cur.execute("drop table students.classbtech")

# %%
cur.execute("drop database student")

# %%
cur.execute("drop database students")

# %%
sql.commit()
