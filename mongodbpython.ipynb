# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://username:password@cluster0.s2vqrms.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#create  a database
database = client["ineuron"]

# %%
# create a collection
coll =database["fsds"]

# %%
data = {
    "class" : "fsds",
    "topic" : "mongodb",
    "date" : "11012025"
}

# %%
# insert data into collection
coll.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6962df8424166746d2337bd8'), acknowledged=True)

# %%
l = [{
    "class" : "fsds",
    "topic" : "mongodb",
    "date" : "11012025"
},
    {
    "class" : "fsds",
    "topic" : "mongodb",
    "date" : "11012025"
},
{
    "class" : "fsds",
    "topic" : "mongodb",
    "date" : "11012025"
}]

# %%
coll.insert_many(l)
# Out:
# InsertManyResult([ObjectId('6962e05924166746d2337bd9'), ObjectId('6962e05924166746d2337bda'), ObjectId('6962e05924166746d2337bdb')], acknowledged=True)

# %%
data1 = {
    "class" : "fsds",
    "topic" : "mongodb",
    "date" : "11012025",
    "task" : "mysql based task",
    "confi" : ["free","ineuron","coll"]
}

# %%
coll.insert_one(data1)
# Out:
# InsertOneResult(ObjectId('6962e21e24166746d2337bdc'), acknowledged=True)

# %%
data2 = {
    "_id" : "ashwani",
    "class" : "fsds",
    "topic" : "mongodb",
    "date" : "11012025",
    "task" : "mysql based task",
    "confi" : ["free","ineuron","coll"]
}

# %%
coll.insert_one(data2)
# Out:
# InsertOneResult('ashwani', acknowledged=True)

# %%
rec =   coll.find()

# %%
rec

# %%
for i in rec:
    print(i)
# Out:
# {'_id': ObjectId('6962df8424166746d2337bd8'), 'class': 'fsds', 'topic': 'mongodb', 'date': '11012025'}
# {'_id': ObjectId('6962e05924166746d2337bd9'), 'class': 'fsds', 'topic': 'mongodb', 'date': '11012025'}
# {'_id': ObjectId('6962e05924166746d2337bda'), 'class': 'fsds', 'topic': 'mongodb', 'date': '11012025'}
# {'_id': ObjectId('6962e05924166746d2337bdb'), 'class': 'fsds', 'topic': 'mongodb', 'date': '11012025'}
# {'_id': ObjectId('6962e21e24166746d2337bdc'), 'class': 'fsds', 'topic': 'mongodb', 'date': '11012025', 'task': 'mysql based task', 'confi': ['free', 'ineuron', 'coll']}
# {'_id': 'ashwani', 'class': 'fsds', 'topic': 'mongodb', 'date': '11012025', 'task': 'mysql based task', 'confi': ['free', 'ineuron', 'coll']}

# %%
from pprint import pprint
for i in rec:
    pprint(i)
# Out:
# {'_id': ObjectId('6962df8424166746d2337bd8'),
#  'class': 'fsds',
#  'date': '11012025',
#  'topic': 'mongodb'}
# {'_id': ObjectId('6962e05924166746d2337bd9'),
#  'class': 'fsds',
#  'date': '11012025',
#  'topic': 'mongodb'}
# {'_id': ObjectId('6962e05924166746d2337bda'),
#  'class': 'fsds',
#  'date': '11012025',
#  'topic': 'mongodb'}
# {'_id': ObjectId('6962e05924166746d2337bdb'),
#  'class': 'fsds',
#  'date': '11012025',
#  'topic': 'mongodb'}
# {'_id': ObjectId('6962e21e24166746d2337bdc'),
#  'class': 'fsds',
#  'confi': ['free', 'ineuron', 'coll'],
#  'date': '11012025',
#  'task': 'mysql based task',
#  'topic': 'mongodb'}
# {'_id': 'ashwani',
#  'class': 'fsds',
#  'confi': ['free', 'ineuron', 'coll'],
#  'date': '11012025',
#  'task': 'mysql based task',
#  'topic': 'mongodb'}

# %%
coll.find_one()
# Out:
# {'_id': ObjectId('6962df8424166746d2337bd8'),
#  'class': 'fsds',
#  'topic': 'mongodb',
#  'date': '11012025'}

# %%
rec2 =coll.find({},{'class'})
for i in rec2:
    pprint(i)
# Out:
# {'_id': ObjectId('6962df8424166746d2337bd8'), 'class': 'fsds'}
# {'_id': ObjectId('6962e05924166746d2337bd9'), 'class': 'fsds'}
# {'_id': ObjectId('6962e05924166746d2337bda'), 'class': 'fsds'}
# {'_id': ObjectId('6962e05924166746d2337bdb'), 'class': 'fsds'}
# {'_id': ObjectId('6962e21e24166746d2337bdc'), 'class': 'fsds'}
# {'_id': 'ashwani', 'class': 'fsds'}

# %%
rec2  = coll.find({"_id" : "ashwani"})

# %%
for i in rec2:
    pprint(i)
# Out:
# {'_id': 'ashwani',
#  'class': 'fsds',
#  'confi': ['free', 'ineuron', 'coll'],
#  'date': '11012025',
#  'task': 'mysql based task',
#  'topic': 'mongodb'}

# %%
rec2  = coll.find({},{"class" : "fsds"})
for i in rec2:
    pprint(i)
# Out:
# {'_id': ObjectId('6962df8424166746d2337bd8'), 'class': 'fsds'}
# {'_id': ObjectId('6962e05924166746d2337bd9'), 'class': 'fsds'}
# {'_id': ObjectId('6962e05924166746d2337bda'), 'class': 'fsds'}
# {'_id': ObjectId('6962e05924166746d2337bdb'), 'class': 'fsds'}
# {'_id': ObjectId('6962e21e24166746d2337bdc'), 'class': 'fsds'}
# {'_id': 'ashwani', 'class': 'fsds'}

# %%
coll.insert_one({"price":"15000"})
# Out:
# InsertOneResult(ObjectId('6962ea9b24166746d2337bdd'), acknowledged=True)

# %%
coll.update_one({"price":"15000"},{'$set' :{"price":18000}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff00000000000002c7'), 'opTime': {'ts': Timestamp(1768090341, 2), 't': 711}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1768090341, 2), 'signature': {'hash': b',\xf7%\xb4\xd0H\x14[\xcc;\xd8V\xae\xbdt44\x81\xbbf', 'keyId': 7533648880890544153}}, 'operationTime': Timestamp(1768090341, 2), 'updatedExisting': True}, acknowledged=True)

# %%
coll.find_one({'price':18000})
# Out:
# {'_id': ObjectId('6962ea9b24166746d2337bdd'), 'price': 18000}

# %%
coll.delete_many({"class":"fsds"})
# Out:
# DeleteResult({'n': 6, 'electionId': ObjectId('7fffffff00000000000002c7'), 'opTime': {'ts': Timestamp(1768090651, 2), 't': 711}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1768090651, 2), 'signature': {'hash': b'\xd2{\x99\xbf\xbe\x8b\xe56\x1b\xa9\x8b\xca\xa4\xa7\xb1=v\xf2K\xa5', 'keyId': 7533648880890544153}}, 'operationTime': Timestamp(1768090651, 2)}, acknowledged=True)
